# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
#
# ## IMPORTANT: Guidelines for a proper conduct of the exercises
# 1. you should create code that is correct, simple, well organized, indented, commented, which uses self-explanatory names for variables and that is numerically efficient.
# 2. I expect a responsible interaction during the exercises: the questions should be more related to the conduction of the exercises and to the meaning of the results obtained than to the computational problems. Bugs are usual in coding; for this reason, sooner or later, one should learn to deal with them by oneself ... if you'll be able to, it will be your main achievement in this Laboratory!
#
# ## <span style="color:blue">  Numerical exercises 1</span>

# %% [markdown]
# ### Exercise 01.1
# - Test the Pseudo-Random Number generator downloaded from the NSL Ariel web site by estimating:

# %% [markdown]
# 1. $\langle r \rangle = \int_0^1 r dr = 1/2$. <font color="red">Make a picture of the estimation of $\langle r \rangle$ and its uncertainty (which corresponds to Standard Deviation of the mean for the estimation of $\langle r \rangle$) with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties).

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

from seaborn import set_theme
set_theme(style="whitegrid")

# %%
def error(AV,AV2,n):  # Function for statistical uncertainty estimation
    if n==0:
        return 0
    else:
        return math.sqrt((AV2[n] - AV[n]**2)/n)

M=100000              # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
np.random.seed(1)     # Fixing random seed for reproducibility
r = np.random.rand(M) # U[0,1) uniform distribution
x = np.arange(N)      # [0,1,2,...,N-1]
ave = np.zeros(N)
av2 = np.zeros(N)
sum_prog = np.zeros(N)
su2_prog = np.zeros(N)
err_prog = np.zeros(N)

for i in range(N):
    sum1 = 0
    sum2 = 0 #PROVA per far vedere come si può sbagliare ad interpretare il calcolo di A_i^2
    for j in range(L):
        k = j+i*L
        sum1 += r[k]
        sum2 += r[k]*r[k] #PROVA
    ave[i] = sum1/L     # r_i 
    #av2[i] = sum2/L     # (r_i)^2 #PROVA
    av2[i] = (ave[i])**2 # (r_i)^2 

for i in range(N):
    for j in range(i+1):
        sum_prog[i] += ave[j] # SUM_{j=0,i} r_j
        su2_prog[i] += av2[j] # SUM_{j=0,i} (r_j)^2
    sum_prog[i]/=(i+1) # Cumulative average
    su2_prog[i]/=(i+1) # Cumulative square average
    err_prog[i] = error(sum_prog,su2_prog,i) # Statistical uncertainty
    
x*=L # Number of throws = block * (Number of throws in each block)
plt.errorbar(x,sum_prog-0.5,yerr=err_prog)
plt.xlabel('#throws')
plt.title('Integral Estimation')
plt.ylabel('<r>-1/2')
plt.grid(True)
plt.show()

# %%
data = np.loadtxt("./eser_1/1_1/data.csv", delimiter=",")
x_mine = np.arange(0, data.shape[0])
n_throws = 100
true_value = 0.5

plt.plot(x_mine * n_throws, data[:, 0] - true_value)
plt.fill_between(
    x_mine * n_throws,
    data[:, 0] - data[:, 1] - true_value,
    data[:, 0] + data[:, 1] - true_value,
    alpha=0.65,
)
plt.xlabel("# Throws")
plt.title("Integral Estimation")
plt.ylabel("extraction - 0.5")
# Out:
# Text(0, 0.5, 'extraction - 0.5')

# %% [markdown]
# As it can be observed, the extimated integral value is compatible with the expected result.

# %% [markdown]
# 2. $\sigma^2 = \int_0^1 (r-1/2)^2 dr = 1/12$. <font color="red">Make a picture of the estimation of $\sigma^2$ and its uncertainty (which corresponds to Standard Deviation of the mean for the estimation of $\langle (r-1/2)^2 \rangle$) with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties).

# %%
# Continue using variables and functions of the previous code cell
ave = np.zeros(N)
av2 = np.zeros(N)
sum_prog = np.zeros(N)
su2_prog = np.zeros(N)
err_prog = np.zeros(N)

for i in range(N):
    sum = 0
    for j in range(L):
        k = j+i*L
        sum += (r[k]-0.5)**2 # Accumulate measures
    ave[i] = sum/L           # Estimate in each block 
    av2[i] = (ave[i])**2 

for i in range(N):
    for j in range(i+1):
        sum_prog[i] += ave[j] 
        su2_prog[i] += av2[j] 
    sum_prog[i]/=(i+1) # Cumulative average
    su2_prog[i]/=(i+1) # Cumulative square average
    err_prog[i] = error(sum_prog,su2_prog,i) # Statistical uncertainty
    
plt.plot(x,sum_prog-1/12)
plt.fill_between(x,sum_prog-err_prog-1/12,sum_prog+err_prog-1/12,alpha=0.65)
plt.xlabel('#throws')
plt.title('Error Estimation')
plt.ylabel('<(r-0.5)^2>-1/12')
plt.grid(True)
plt.show()

# %%
sigma = np.loadtxt("eser_1/1_1/sigma.csv", delimiter=',')
true_value = 1/12
plt.errorbar(x_mine * n_throws, sigma[:, 0] - true_value, yerr=sigma[:,1])
plt.xlabel("Nr Throws")
plt.ylabel("extraction - 1/12")
plt.title('Error Estimation')
# Out:
# Text(0.5, 1.0, 'Error Estimation')

# %% [markdown]
# The error extimation also is close to the expected value.

# %% [markdown]
# The hypothesis is that the numbers $r$ are drawn from a uniform distribution. In Statistics we cannot prove that some random events are drawn from a particular distribution (Note, in fact, that such hypothesis is false: pseudo-random numbers are drawn from a deterministic algorithm!); we can try to estimate the probability that $r$ **are not** drawn from a uniform distribution. If this probability is low, we can safely reject this last hypothesis.
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
# Pearson's cumulative test statistic $\chi^2$ is a measure of the error between observations, $O_i$, and expected values, $E_i$:
# $$\chi^2 = \sum_{i} \frac{\left( O_i - E_i \right)^2}{E_i}$$
# The numerator is a squared distance between observations, $O_i$, and expected values, $E_i$, and thus should be compared (at the denominator) with the expected squared fluctuations (variance) of the relative distribution. Why variance = $E_i$?
# The probability of getting exactly $k$ (independent) successes, each one with probability $p$, in $n$ trials is given by the Binomial distribution (see <a href="https://en.wikipedia.org/wiki/Binomial_distribution">this Wikipedia link</a>):
# $$Pr(X=k) = {{n}\choose{k}} p^k (1-p)^{n-k} = \frac{n!}{k! (n-k)!} p^k (1-p)^{n-k}$$
# The average of the Binomial distribution is $\langle X \rangle = np$, the variance is: $\sigma^2 = np (1-p)$. Thus if $p$ is small we have that $\sigma^2 \simeq np$, that is $\sigma^2 \simeq \langle X \rangle$ and this explains the denominator $E_i$ in $\chi^2$
# </p>
#
# 3. Divide $[0,1]$ into $M$ identical sub-intervals and implement the $\chi^2$ test. Obviously, the number of expected events observed in each sub-interval after $n$ *throws*, according to a uniform distribution, is $np = n\times 1/M= n/M$. Fix $M=10^2$ and use for $n$ the first $10^4$ pseudo-random numbers, then the successive $10^4$ pseudo-random numbers, and so on ... 100 times. <font color="red">Plot $\chi^2_j$ for $j=1, ..., 100$</font>. In this case the chi-square statistic is:
# $$\chi^2 = \sum_{i=1}^M \frac{\left( n_i - n/M \right)^2}{n/M}$$
# We should expect on average that $(n_i - n/M)^2 \simeq n/M$ and thus $\chi^2 \simeq 100$, i.e. the number of sub-intervals.
# A larger value of $\chi^2$ indicates that the hypothesis ($n_i$ are drawn from a uniform distribution) is rather unlikely ... <font color="red">but before judging</font>, you could compare the histogram of the values obtained for $\chi^2_j$ with the true probability distribution (see: <a href="https://en.wikipedia.org/wiki/Chi-squared_distribution">this Wikipedia link</a>).

# %%
from scipy.stats import chi2
dat_chi_square = np.loadtxt('eser_1/1_1/chi_square.csv', delimiter = ',')
print(f'{dat_chi_square=}')
rv = chi2(100)
val,pos, _ = plt.hist(dat_chi_square, bins=20, density=True, label='Data PDF')
# print(rv.pdf(pos.max())
x_chi = np.linspace(np.min(pos), np.max(pos))
plt.plot(x_chi, rv.pdf(x_chi), label=r'$\chi^2$ with 100 freedom degrees')
param_fitted = chi2.fit(dat_chi_square, floc=0, fscale=1)
print(f'{param_fitted=}')

plt.plot(x_chi, chi2.pdf(x_chi, *param_fitted), label=r'$\chi^2$ fitted from data, df : ' + f'{param_fitted[0]:.2f}')
plt.title(r"Density of $\chi^2$")
plt.xlabel(r"$\chi^2$")
plt.ylabel("Density")
plt.legend();
# Out:
# dat_chi_square=array([103.36,  85.14,  98.9 ,  87.92, 105.1 , 137.16,  85.74,  99.54,
#         95.92, 121.64,  93.22,  79.1 ,  85.02,  90.42,  99.06, 121.22,
#         99.92,  88.56, 102.92, 120.98,  86.22, 116.78, 123.8 ,  92.56,
#         98.02, 102.34,  92.34, 103.16,  79.44, 123.34,  88.9 ,  90.88,
#        106.58,  94.46, 101.5 ,  85.52, 105.  , 133.22,  96.64,  95.16,
#        102.76, 107.68, 113.9 , 115.6 , 113.24, 109.42, 115.5 , 104.76,
#        106.86,  92.06, 132.08, 100.28, 105.66,  99.08,  81.88, 102.14,
#         88.8 ,  94.56,  91.84, 108.66, 120.68,  85.96,  85.92,  86.64,
#         94.  ,  88.9 , 107.42, 102.5 , 113.28, 118.88,  94.4 ,  90.5 ,
#         88.86,  89.36,  75.46,  90.92,  87.54,  84.2 , 116.44, 126.02,
#         89.98,  97.86,  84.8 , 100.22,  82.34,  78.96,  87.86, 126.68,
#         83.14, 108.58, 117.26, 116.42,  81.04,  97.44,  79.22,  99.66,
#        100.22,  95.24,  89.88, 108.24])
# param_fitted=(np.float64(99.84677734375018), 0, 1)

# %% [markdown]
# We made a fit of the data with a chi square distribution provided by scipy. The fit result is a chi square distribution with around 100 degrees of freedom. This is the expected result for the problem, so we can expect that the numbers are effectively extracted with a uniform distribution.

# %% [markdown]
# ### Exercise 01.2
# - Extend Pseudo-Random Number generator downloaded from the NSL Ariel web site and check the Central Limit Theorem:

# %% [markdown]
# 1. <font color="red">Add two probability distributions</font> by using the **method of the inversion of the cumulative distribution** to sample from a **generic** <font color="red">exponential distribution</font>, $p(x) = \lambda \exp(-\lambda x)$, $x\in [0;+\infty]$ (see <a href="https://en.wikipedia.org/wiki/Exponential_distribution">this Wikipedia link</a>), and a **generic** <font color="red">Cauchy-Lorentz distribution</font> $p(x)=\frac{1}{\pi}\frac{\Gamma}{(x-\mu)^2+\Gamma^2}$, $x\in [-\infty;+\infty]$ (see <a href="https://en.wikipedia.org/wiki/Cauchy_distribution">this Wikipedia link</a>).
# 2. <font color="red">Make 3 pictures</font> with the histograms obtained filling them with $10^4$ realizations of $S_N = \frac{1}{N}\sum_{i=1}^N x_i$ (for $N=1, 2, 10, 100$), being $x_i$ a random variable sampled throwing a *standard* dice (fig.1), an *exponential* dice (fig.2, use $\lambda=1$) and a *Lorentzian* dice (fig.3, use $\mu=0$ and $\Gamma=1$).
#
# Note tha you can try to fit the case $N=100$ with a Gaussian for standard and exponential dices, whereas you should use a Cauchy-Lorentz distribution for the last case.

# %%
data = [
    ["uniform_1",np.loadtxt("eser_1/1_2/uniform_1.dat")],
    ["uniform_2",np.loadtxt("eser_1/1_2/uniform_2.dat")],
    ["uniform_10",np.loadtxt("eser_1/1_2/uniform_10.dat")],
    ["uniform_100",np.loadtxt("eser_1/1_2/uniform_100.dat")],
    ["exponential_1",np.loadtxt("eser_1/1_2/exponential_1.dat")],
    ["exponential_2",np.loadtxt("eser_1/1_2/exponential_2.dat")],
    ["exponential_10",np.loadtxt("eser_1/1_2/exponential_10.dat")],
    ["exponential_100",np.loadtxt("eser_1/1_2/exponential_100.dat")],
    ["cauchy_1",np.loadtxt("eser_1/1_2/cauchy_1.dat")],
    ["cauchy_2",np.loadtxt("eser_1/1_2/cauchy_2.dat")],
    ["cauchy_10",np.loadtxt("eser_1/1_2/cauchy_10.dat")],
    ["cauchy_100",np.loadtxt("eser_1/1_2/cauchy_100.dat")],
]

fig, axes = plt.subplots(3, 4, figsize=(10, 10.5), layout='constrained')

for ax, dat in zip(axes.ravel(), data):
    if "cauchy" in dat[0]:
        ax.hist(dat[1], bins=50, range=(-10, 10), edgecolor='none')
        ax.set_xlabel('Extracted Value')
        ax.set_ylabel('Frequency')
    else:
        ax.hist(dat[1], bins=50, edgecolor='none')
        ax.set_xlabel('Extracted Value')
        ax.set_ylabel('Frequency')

fig.suptitle('Central Limit Theorem')
# Out:
# Text(0.5, 0.98, 'Central Limit Theorem')

# %% [markdown]
# ## Figure 1 : Uniform Distribution

# %%
import scipy.stats as stats

# %%
fig, axs = plt.subplots(1, 4, figsize=(13,5), layout = 'constrained', sharey = True)

values = [1, 2, 10, 100]

for ax, dat, val in zip(axs, data[0:4], values):
    params = stats.norm.fit(dat[1], loc=0, scale=0)
    x = np.linspace(np.min(dat[1]), np.max(dat[1])) 
    ax.plot(x, stats.norm.pdf(x, *params), color = 'C1', label=f'$\mu$ : {params[0]:.2f}\n$\sigma$ : {params[1]:.2f}')
    ax.hist(dat[1], bins=50, histtype="stepfilled", density = True, label='values')
    ax.set_xlabel("$S_n$")
    ax.set_title(f'Mean of {val}')
    ax.legend()

axs[0].set_ylabel('Count')
fig.suptitle('Uniform Distribution');
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_35911/1866517997.py:8: SyntaxWarning: invalid escape sequence '\m'
#   ax.plot(x, stats.norm.pdf(x, *params), color = 'C1', label=f'$\mu$ : {params[0]:.2f}\n$\sigma$ : {params[1]:.2f}')
# /tmp/ipykernel_35911/1866517997.py:8: SyntaxWarning: invalid escape sequence '\s'
#   ax.plot(x, stats.norm.pdf(x, *params), color = 'C1', label=f'$\mu$ : {params[0]:.2f}\n$\sigma$ : {params[1]:.2f}')

# %% [markdown]
# The distribution was fitted with a normal distribution, as it can be seen, the histogram fits better a normal distribution when the number of elements of the mean increases.
#
# Increasing the values of aleatory variables used during the mean produces a normal distribution with the same mean, but a reduced variance.
#
# It can be expected that a uniform distribution tends to a gaussian, that is the actractor for distribution with a defined variance and mean value.

# %% [markdown]
# ## Figure 2 : Exponential Distribution

# %%
fig, axs = plt.subplots(1, 4, figsize=(11,4), layout = 'constrained', sharey = True)

for ax, dat, val in zip(axs, data[4:8], values):
    params = stats.norm.fit(dat[1], loc=0, scale=0)
    x = np.linspace(np.min(dat[1]), np.max(dat[1])) 
    ax.plot(x, stats.norm.pdf(x, *params), color = 'C1', label=f"$\mu$ : {params[0]:.2f}\n$\sigma$ : {params[1]:.2f}")
    ax.hist(dat[1], bins=100, histtype='stepfilled', density = True, label='values')
    ax.set_xlabel("$S_n$")
    ax.set_title(f'Mean of {val}')
    ax.legend()

axs[0].set_ylabel('Count')
fig.suptitle('Exponential Distribution')
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_35911/433236195.py:6: SyntaxWarning: invalid escape sequence '\m'
#   ax.plot(x, stats.norm.pdf(x, *params), color = 'C1', label=f"$\mu$ : {params[0]:.2f}\n$\sigma$ : {params[1]:.2f}")
# /tmp/ipykernel_35911/433236195.py:6: SyntaxWarning: invalid escape sequence '\s'
#   ax.plot(x, stats.norm.pdf(x, *params), color = 'C1', label=f"$\mu$ : {params[0]:.2f}\n$\sigma$ : {params[1]:.2f}")
# Text(0.5, 0.98, 'Exponential Distribution')

# %% [markdown]
# Also in this case the distribution tends to a normal distribution.

# %% [markdown]
# ## Figure 3 : Lorentzian Distribution

# %%
fig, axs = plt.subplots(1, 4, figsize=(16,5), layout = 'constrained', sharey = True)

for ax, dat, val in zip(axs, data[8:], values):
    params = stats.cauchy.fit(dat[1], loc=0, scale=0)
    x = np.linspace(-10, 10) 
    ax.plot(x, stats.cauchy.pdf(x, *params), color = 'C1', label=f'$\mu$ : {params[0]:.2f}\nFWHM : {params[1]:.2f}')
    ax.hist(dat[1], bins=100, histtype='stepfilled', range=(-10, 10), density=True, label = 'values')
    ax.set_xlabel("S_n")
    ax.set_title(f'Mean of {val}')
    ax.legend(loc = 'upper left')

axs[0].set_ylabel('Count')
fig.suptitle('Lorentzian Distribution')
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_35911/3081787541.py:6: SyntaxWarning: invalid escape sequence '\m'
#   ax.plot(x, stats.cauchy.pdf(x, *params), color = 'C1', label=f'$\mu$ : {params[0]:.2f}\nFWHM : {params[1]:.2f}')
# Text(0.5, 0.98, 'Lorentzian Distribution')

# %% [markdown]
# In the case of a Lorentzian distribution, the local actractor it is still a Lorentzian distribution, this is due to the fact that for the lorentzian the second moment, so the variance, does not converge, so it isn't defined.

# %% [markdown]
# ### Exercise 01.3
# - **Simulate** the Buffon’s experiment (see LSN_Lecture_00, supplementary material):  A needle of length $L$ is thrown at random onto a horizontal plane ruled with straight lines a distance $d$ (must be $d > L$, but do not use $d\gg L$ otherwise $P\ll 1$) apart. The probability $P$ that the needle will intersect one of these lines is: $P = 2L/\pi d$. This could be used to evaluate $\pi$ from throws of the needle: if the needle is thrown down $N_{thr}$ times and is observed to land on a line $N_{hit}$ of those times, we can make an estimate of $\pi$ from
# $$\pi = \frac{2L}{Pd} = \lim_{N_{thr} \to \infty}\frac{2LN_{thr}}{N_{hit}d}$$
# <font color="red">Make a picture of the estimation of $\pi$ and its uncertainty (Standard Deviation of the mean) with a large number of *throws* $M$ as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties). If possible, do not use $\pi$ to evaluate $\pi$.

# %%
buffon_data = np.loadtxt("eser_1/1_3/buffon.csv", delimiter=',')
x_buffon = np.arange(0, buffon_data.shape[0])

# plt.errorbar(x_buffon * 1e4, buffon_data[:, 0] - np.pi, buffon_data[:, 1])
plt.plot(x_buffon * 1e4, buffon_data[:, 0] - np.pi)
plt.fill_between(x_buffon * 1e4, buffon_data[:, 0] - buffon_data[:, 1] - np.pi, buffon_data[:, 0] + buffon_data[:, 1] - np.pi, alpha=0.65)
plt.ylabel('value - $\pi$')
plt.xlabel("nr throws")
plt.title('$\pi$ estimation')
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:9: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:9: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_35911/723687853.py:7: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('value - $\pi$')
# /tmp/ipykernel_35911/723687853.py:9: SyntaxWarning: invalid escape sequence '\p'
#   plt.title('$\pi$ estimation')
# Text(0.5, 1.0, '$\\pi$ estimation')

# %% [markdown]
# To generate the random numbers an accept reject method was used:
#
# - extract a couple $x,y \in [-1, 1] \times [-1, 1]$
# - if $N = \sqrt{x^2 + y^2} \le 1$ then return $x / N$.
# - else generate a new couple $(x,y)$.
#
# To generate an effective needle we only need a starting x, and an ending x to check if there is an intersection. The y choords are not needed.

# %% [markdown]
# ### <span style="color:blue">Computing statistical uncertainties: the blocking method</span>
# - A fundamental step in every Monte Carlo calculation is the estimation of its statistical uncertainty, **it's a must!** Your task would not be completed if you had not calculated it.

# %% [markdown]
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     In computing the statistical uncertainties, i.e. the standard deviation of the mean, you need an estimation of the variance $\sigma^2$, the second central moment. First of all note that the variance can be computed from
#     $$\sigma^2_A := \langle (A-\langle A\rangle)^2\rangle = \langle A^2 \rangle -\langle A\rangle^2 $$
#     What is the best way to estimate $\sigma^2_A$? Imagine that your Monte Carlo estimation of $A$ is obtained from a calculation which uses $M$ Monte Carlo "steps" (intentionally, here I am generic because what is a single "step" in a Monte Carlo calculation strictly depends on the specific calculation); you can always divide such $M$ Monte Carlo "steps" in $N$ blocks, with $N<M$. In each block, you can use your $M/N$ Monte Carlo "steps" to obtain an estimate of $A$, let me call it $A_i$ with $i=1,N$, and then you have also $A^2_i$ with $i=1,N$.
#     At this point everything becomes clear:
#     $$ \langle A^2 \rangle \simeq \frac{1}{N} \sum_{i=1}^N A^2_i \quad \quad \langle A\rangle^2 \simeq \left( \frac{1}{N} \sum_{i=1}^N A_i \right)^2 $$
#     and finally the statistical uncertainty with $N$ :
#     $$\frac{\sigma}{\sqrt{N-1}} \simeq \sqrt{\frac{1}{N-1} \left[ \frac{1}{N} \sum_{i=1}^N A^2_i - \left( \frac{1}{N} \sum_{i=1}^N A_i \right)^2 \right]} $$
# </p>

# %% [markdown]
# - <font color="blue">In a Monte Carlo calculation, you can use the arguments above to outputting an estimate of A and its statistical uncertainty on the fly, during your calculation. You will be able to do this every $M/N$ steps, and thus, in the end, $N$ times</font>. Note that after the first $M/N$ Monte Carlo steps, at the end of the first block, your estimation of the uncertainty is not computable, so set it to zero and compute it only from the second block. **Question**: $N$ can be chosen in many ways ... what are the limitations regarding this choice?
